# %%
import pandas as pd 
patient_info_path = "patient_info.csv"
features_path = "features.csv"
cpt_path = "CPT_II_ConnersContinuousPerformanceTest.csv"
patient_df = pd.read_csv(patient_info_path,sep=";",index_col=["ID"])
features_df = pd.read_csv(features_path,sep=";",index_col=["ID"])
cpt_df = pd.read_csv(cpt_path,sep=";",index_col=["ID"])

# %%
patient_df
# Out:
#      SEX  AGE  ACC  ACC_TIME  ACC_DAYS  HRV  HRV_TIME  HRV_HOURS  CPT_II  \
# ID
# 1      0    3    1  16:00:00       6.0    1  11:00:00       21.0       0
# 2      0    4    1  10:54:00       6.8    0       NaN        NaN       1
# 3      1    2    1  15:28:00       7.2    1  15:25:00       21.0       1
# 4      1    3    0       NaN       NaN    1  16:55:00       22.0       1
# 5      1    1    1  14:24:00       5.9    1  16:00:00       12.0       1
# ..   ...  ...  ...       ...       ...  ...       ...        ...     ...
# 103    1    4    0       NaN       NaN    1  09:26:00       22.0       1
# 104    0    2    1  12:08:00       7.3    1  12:00:00       22.0       1
# 105    1    4    1  12:30:00       6.4    1  13:25:00       13.0       1
# 106    0    3    0       NaN       NaN    0       NaN        NaN       1
# 108    1    3    1  10:15:00       6.6    0       NaN        NaN       1
#
#      ADHD  ...  HADS_D  MED  MED_Antidepr  MED_Moodstab  MED_Antipsych  \
# ...

# %%
features_df
# Out:
#     ACC__variance_larger_than_standard_deviation  ACC__has_duplicate_max  \
# ID
# 1                                            1.0                     0.0
# 2                                            1.0                     1.0
# 3                                            1.0                     0.0
# 5                                            1.0                     0.0
# 7                                            1.0                     0.0
# ..                                           ...                     ...
# 94                                           1.0                     0.0
# 95                                           1.0                     0.0
# 96                                           1.0                     0.0
# 97                                           1.0                     0.0
# 98                                           1.0                     0.0
#
#     ACC__has_duplicate_min  ACC__has_duplicate  ACC__sum_values  \
# ID
# ...

# %%
cpt_df
# Out:
#      Assessment Status  Assessment Duration  Type  LastTrial  Trial1  \
# ID
# 2                    3               839999     6        360      11
# 3                    3               839999     6        360      12
# 4                    3               839999     6        360      14
# 5                    3               839999     6        360      12
# 7                    3               839998     6        360      11
# ..                 ...                  ...   ...        ...     ...
# 103                  3               840000     6        360       0
# 104                  3               840000     6        360      10
# 105                  3               839999     6        360      12
# 106                  3               840000     6        360       2
# 108                  3               840000     6        360       4
#
#      Response1  Trial2  Response2  Trial3  Response3  ...  Raw Score HitRTIsi  \
# ...

# %%
patient_df.describe()
# Out:
#               SEX         AGE         ACC   ACC_DAYS         HRV  HRV_HOURS  \
# count  103.000000  103.000000  103.000000  85.000000  103.000000  80.000000
# mean     0.514563    2.330097    0.825243   6.916471    0.776699  20.750000
# std      0.502232    1.042135    0.381616   1.160649    0.418495   4.113885
# min      0.000000    1.000000    0.000000   2.200000    0.000000   5.000000
# 25%      0.000000    1.000000    1.000000   6.600000    1.000000  18.750000
# 50%      1.000000    2.000000    1.000000   7.000000    1.000000  22.000000
# 75%      1.000000    3.000000    1.000000   7.300000    1.000000  24.000000
# max      1.000000    4.000000    1.000000  10.100000    1.000000  27.000000
#
#            CPT_II        ADHD         ADD     BIPOLAR  ...     HADS_D  \
# count  103.000000  103.000000  103.000000  103.000000  ...  88.000000
# mean     0.961165    0.495146    0.223301    0.407767  ...   5.159091
# std      0.194146    0.502421    0.418495    0.493822  ...   4.034012
# ...

# %%
features_df.describe()
# Out:
#        ACC__variance_larger_than_standard_deviation  ACC__has_duplicate_max  \
# count                                         116.0              116.000000
# mean                                            1.0                0.137931
# std                                             0.0                0.346324
# min                                             1.0                0.000000
# 25%                                             1.0                0.000000
# 50%                                             1.0                0.000000
# 75%                                             1.0                0.000000
# max                                             1.0                1.000000
#
#        ACC__has_duplicate_min  ACC__has_duplicate  ACC__sum_values  \
# count                   116.0               116.0     1.160000e+02
# mean                      1.0                 1.0     3.238148e+06
# std                       0.0                 0.0     2.069070e+06
# ...

# %%
cpt_df.describe()
# Out:
#        Assessment Status  Assessment Duration  Type  LastTrial     Trial1  \
# count               99.0            99.000000  99.0       99.0  99.000000
# mean                 3.0        839999.262626   6.0      360.0   7.636364
# std                  0.0             0.898818   0.0        0.0   4.641109
# min                  3.0        839997.000000   6.0      360.0   0.000000
# 25%                  3.0        839998.000000   6.0      360.0   4.000000
# 50%                  3.0        840000.000000   6.0      360.0   8.000000
# 75%                  3.0        840000.000000   6.0      360.0  11.000000
# max                  3.0        840000.000000   6.0      360.0  15.000000
#
#         Response1     Trial2   Response2     Trial3   Response3  ...  \
# count   99.000000  99.000000   99.000000  99.000000   99.000000  ...
# mean   407.000000   7.525253  334.151515   6.454545  302.383838  ...
# std    341.600315   4.910097  212.935526   4.708379  174.283648  ...
# ...

# %%
patient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103 entries, 1 to 108
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SEX                     103 non-null    int64
#  1   AGE                     103 non-null    int64
#  2   ACC                     103 non-null    int64
#  3   ACC_TIME                85 non-null     object
#  4   ACC_DAYS                85 non-null     float64
#  5   HRV                     103 non-null    int64
#  6   HRV_TIME                80 non-null     object
#  7   HRV_HOURS               80 non-null     float64
#  8   CPT_II                  103 non-null    int64
#  9   ADHD                    103 non-null    int64
#  10  ADD                     103 non-null    int64
#  11  BIPOLAR                 103 non-null    int64
#  12  UNIPOLAR                103 non-null    int64
#  13  ANXIETY                 103 non-null    int64
# ...

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116 entries, 1 to 98
# Columns: 787 entries, ACC__variance_larger_than_standard_deviation to ACC__matrix_profile__feature_"75"__threshold_0.98
# dtypes: float64(787)
# memory usage: 714.1 KB

# %%
cpt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 2 to 108
# Columns: 785 entries, Assessment Status to Old Overall Index
# dtypes: float64(51), int64(734)
# memory usage: 607.9 KB

# %%
patient_df=patient_df.dropna(axis=1)
features_df = features_df.dropna(axis=1)
cpt_df = cpt_df.dropna(axis=1)

# %%
patient_df = patient_df.drop_duplicates()
features_df = features_df.drop_duplicates()
cpt_df = cpt_df.drop_duplicates()
